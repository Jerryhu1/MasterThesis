# %%
import initialisation
import modelTrainer
import musicPlayer
import simulation
import fitness
import individual
import music21
import collections
import importlib
import numpy as np
import pandas as pd
import duration
import constants
import random

from music21 import *

# %%
importlib.reload(initialisation)
importlib.reload(modelTrainer)
importlib.reload(musicPlayer)
importlib.reload(simulation)
importlib.reload(fitness)
importlib.reload(duration)
importlib.reload(music21)
importlib.reload(individual)
importlib.reload(constants)
# Out:
# <module 'constants' from 'C:\\School\\Master\\Thesis\\Programming\\MasterThesis\\EvoMusicCompanion\\constants.py'>

# %%
# Add gregorian corpus
localCorpus = corpus.corpora.LocalCorpus()
greg_corpus = corpus.corpora.LocalCorpus('greg')
print(greg_corpus.existsInSettings)
greg_corpus.addPath('./midi')
greg_corpus.save()
print(greg_corpus.existsInSettings)

# %%
corpus.corpora.LocalCorpus('greg').metadataBundle[0].parse()
# Out:
# <music21.stream.Score 0x1ac17c0df98>

# %%
greg = corpus.corpora.LocalCorpus('greg').metadataBundle

scores = []

for i in greg[0:100]:
    scores.append(i.parse())

# %%
it = scores[0].parts[0].getElementsByClass(stream.Measure)
for i in it:
    print(i)

# %%
measures = len(score[0].getElementsByClass(stream.Part)[0].getElementsByClass(stream.Measure))
# Get a part of the piece
noteIterator = score[0].parts[0].getElementsByClass(stream.Measure).flat.getElementsByClass('Note')
allNotes = []

for el in noteIterator:
    if('-' in el.nameWithOctave):
        noteName = el.pitch.getEnharmonic().nameWithOctave
        allNotes.append(noteName)
    else:
        noteName = el.nameWithOctave
        allNotes.append(noteName)
# Out:
# <music21.stream.Score 0x1ac17cc3a58>

# %%
pitch_matrix = modelTrainer.train_pitch_matrix(scores);

# %%
sum(pitch_matrix['C4'])
# Out:
# 1.0

# %%
list(filter(lambda (t,v): music21.note.Note(t) > music21.note.Note('C4') , pitch_matrix['C4']))
# Out:
#   File "<ipython-input-43-3ef91da9cd25>", line 1
#     list(filter(lambda (t,v): music21.note.Note(t) > music21.note.Note('C4') , pitch_matrix['C4']))
#                        ^
# SyntaxError: invalid syntax

# %%
pitch_matrix
# Out:
#           C4        A4        G4   G5     D4   B3                  F5  \
# C4  0.094637  0.000000  0.004203  0.0  0.161  0.0  0.161616  0.000000
# A4  0.000000  0.179099  0.372425  0.0  0.036  0.0  0.090909  0.000000
# G4  0.015773  0.338374  0.154687  0.0  0.050  0.0  0.272727  0.000000
# G5  0.000000  0.000000  0.000000  0.0  0.000  0.0  0.000000  0.069444
# D4  0.574132  0.006720  0.012190  0.0  0.234  0.0  0.111111  0.000000
# B3  0.003155  0.000000  0.000000  0.0  0.000  0.0  0.000000  0.000000
#     0.003155  0.011425  0.009668  0.0  0.024  0.0  0.000000  0.000000
# F5  0.000000  0.000000  0.000000  0.6  0.000  0.0  0.000000  0.118056
# F4  0.135647  0.062500  0.231610  0.0  0.226  0.0  0.222222  0.000000
# A3  0.000000  0.000000  0.000000  0.0  0.008  1.0  0.010101  0.000000
# C5  0.000000  0.146169  0.061791  0.0  0.000  0.0  0.000000  0.020833
# D5  0.000000  0.016465  0.015553  0.0  0.000  0.0  0.000000  0.083333
# E4  0.173502  0.005712  0.055906  0.0  0.261  0.0  0.101010  0.000000
# A5  0.000000  0.000000  0.000000  0.2  0.000  0.0  0.000000  0.000000
# B4  0.000000  0.228831  0.071879  0.0  0.000  0.0  0.030303  0.000000
# E5  0.000000  0.004704  0.010088  0.2  0.000  0.0  0.000000  0.708333
#
#           F4   A3        C5        D5        E4        A5        B4        E5
# C4  0.008419  1.0  0.000000  0.000000  0.082073  0.000000  0.000000  0.000000
# A4  0.114251  0.0  0.208858  0.027496  0.007559  0.000000  0.368829  0.001718
# G4  0.318100  0.0  0.026006  0.010130  0.138229  0.000000  0.089545  0.003436
# G5  0.000000  0.0  0.000000  0.002171  0.000000  0.666667  0.000000  0.000000
# D4  0.162959  0.0  0.000000  0.000000  0.273218  0.000000  0.000000  0.000000
# B3  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#     0.001203  0.0  0.000000  0.000000  0.012959  0.000000  0.001452  0.000000
# F5  0.000000  0.0  0.001625  0.015919  0.000000  0.333333  0.001452  0.151203
# F4  0.165364  0.0  0.000000  0.000000  0.384449  0.000000  0.001936  0.000000
# A3  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# C5  0.007216  0.0  0.209265  0.431983  0.000000  0.000000  0.343175  0.073883
# D5  0.000000  0.0  0.185291  0.230825  0.000000  0.000000  0.079864  0.591065
# E4  0.212868  0.0  0.000000  0.000000  0.101512  0.000000  0.000968  0.000000
# A5  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B4  0.009621  0.0  0.351483  0.067294  0.000000  0.000000  0.094385  0.072165
# E5  0.000000  0.0  0.017473  0.214182  0.000000  0.000000  0.018393  0.106529

# %%
get_pitch_transition_by_contour('C4', 'h', pitch_matrix)
# Out:
# 0.0
# 0.015772870662460567
# 0.0
# 0.5741324921135647
# 0.0
# 0.13564668769716087
# 0.0
# 0.0
# 0.17350157728706625
# 0.0
# 0.0
# 0.0
# ('A4', 0.0)
# ('G4', 0.015772870662460567)
# ('G5', 0.0)
# ('D4', 0.5741324921135647)
# (' ', 0.0031545741324921135)
# ('F5', 0.0)
# ('F4', 0.13564668769716087)
# ('C5', 0.0)
# ('D5', 0.0)
# ('E4', 0.17350157728706625)
# ('A5', 0.0)
# ('B4', 0.0)
# ('E5', 0.0)

# %%
music21.note.Note('A4').pitch > music21.note.Note('C4').pitch
# Out:
# True

# %%
def get_pitch_transition_by_contour(pitch, contour, matrix):
    
    transitions = matrix[pitch]

    t_contour = {}

    if contour == 'h':
        for k, v in transitions.iteritems():
            if k == ' ':
                t_contour[k] = v
                continue
            if(music21.note.Note(k) > music21.note.Note(pitch)):
                t_contour[k] = v
                print(t_contour[k])
            
            
    rng = random.random()
    p_sum = 0.0
    # Normalize probability
    p_total = sum(t_contour.values())

    for k, v in t_contour.items():
        t_contour[k] = t_contour[k] / p_total
        if p_sum < rng < p_sum + t_contour[k]:
            return k
        else:
            p_sum += v
