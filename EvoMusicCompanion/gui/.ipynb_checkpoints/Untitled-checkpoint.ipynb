# %%
import gui
import importlib

# %%
pieces = [1,2,3,4]
rating_buttons = [
    button = Button(rating_frame, text="", bg='#EF1C1C'),
    button = Button(rating_frame, text="", bg='#FF8A00'),
    button = Button(rating_frame, text="", bg='#FFF500'),
    button = Button(rating_frame, text="", bg='#4AD10A'),
    button = Button(rating_frame, text="", bg='#0B8F00')
]

# %%
import tkinter as tk
import tkinter.font as tkFont

from tkinter import *

HEIGHT = 1024
WIDTH = 1440
PRIMARY_COLOR = '#ff2345'
SECONDARY_COLOR = '#2A2A2A'
WHITE = '#f3f3f3'
PIANO_ROLL_BG_WHITE = '#f1f1f1'
root = Tk()
font = tkFont.Font(root=root, family="Lato Regular", size=12)

canvas = tk.Canvas(root, height=HEIGHT, width=WIDTH)
canvas.pack()

mainframe = tk.Frame(root, bg = WHITE )

piece_index = 0
mainframe.place(relwidth=1.0, relheight=1.0)

leftframe = tk.Frame(mainframe, bg = SECONDARY_COLOR)
leftframe.place(relwidth=0.20, relheight=1.0)

label = Label(leftframe, text="EvoMusic", bg = SECONDARY_COLOR, fg=WHITE, font=font)
label.place(relwidth=0.8, relx=0.1, rely=0.005)

button = Button(leftframe, text="Test", bg=PRIMARY_COLOR, fg=WHITE)
button.place(relx=0.1, rely=0.1)

topframe = tk.Frame(mainframe, bg = SECONDARY_COLOR)
topframe.place(relwidth=0.8, relheight=0.1, relx=0.2)

curr_song_label = Label(topframe, text="Song 1/5", bg = SECONDARY_COLOR, fg=WHITE, font=font)
curr_song_label.config(anchor=CENTER)
curr_song_label.pack()

# Music frame
musicWindow(mainframe, None)

musicframe = tk.Frame(mainframe, bg = WHITE)
musicframe.place(relx=0.2, rely=0.1, relwidth=1.0, relheight=0.8)

piano_frame = tk.Frame(musicframe, bg=WHITE)
piano_frame.place(relx=0.0, relwidth=0.8, relheight=0.5)

#p_canvas = Canvas(piano_frame, width=1000, height=800, bg=WHITE)
#p_canvas.pack()
#p_canvas.create_rectangle(0, 0, 100, 100, fill=PRIMARY_COLOR)
for p in range(len(pieces)):
    piece = pieces[p]
    piece_button = Button(piano_frame, text=f"Measure: {p}", bg=PRIMARY_COLOR, fg=WHITE, padx=20, pady=20)
    piece_button.grid(row=0, column=p+1, padx=90)
    for i in range(4)
    button = Button(piano_frame, text="Test", bg=PRIMARY_COLOR, fg=WHITE)
    

# Music rating frame
rating_frame = tk.Frame(musicframe, bg=WHITE)
rating_frame.place(relx=0.0, rely=0.5, relwidth=0.8, relheight=0.2)
button = Button(rating_frame, text="Test", bg=PRIMARY_COLOR, fg=WHITE)
button.place(relx=0.1, rely=0.1)

#Lower frame
lowerframe = tk.Frame(mainframe, bg=SECONDARY_COLOR)
lowerframe.place(relx=0.2, rely=0.9, relwidth=1.0, relheight=0.1)
root.mainloop()


def piano_octave(frame):
    piano_frame = tk.Frame(frame)
    p_canvas = tk.Canvas(piano_frame)
    p_canvas.pack()
    p_canvas.create_rectangle(0, 0, 50, 50, fill=PRIMARY_COLOR)
    piano_frame.place()
